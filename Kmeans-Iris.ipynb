# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
iris = sns.load_dataset('iris')
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df = iris[['sepal_length','sepal_width','petal_length','petal_width']]
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
species = iris['species'].map({'setosa':1,'virginica':2,'versicolor':3})

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pcs = pca.fit_transform(df)
plt.scatter(pcs[:,0],pcs[:,1], c=species)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3)
y_means = kmeans.fit_predict(pcs)
plt.scatter(pcs[:,0],pcs[:,1], c=y_means)
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3, init='k-means++')
y_means_init = kmeans.fit_predict(pcs)
plt.scatter(pcs[:,0],pcs[:,1], c=y_means_init)
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
df2 = df[['sepal_length','petal_length']]

# %%
df3 = iris[['sepal_length','petal_length','species']]

# %%
kmeans2 = KMeans(n_clusters=3, init='k-means++')
y_pred_df2 = kmeans2.fit_predict(df2)
plt.scatter(df2['sepal_length'],df2['petal_length'], c=y_pred_df2)
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
plt.scatter(df3['sepal_length'],df3['petal_length'], c=species)
